# %% [markdown]
# ## Part 3: Environmental Benifits of Transit
#
# Assume that each driveway has two cars and that all people work in downtown Kingston, how many new
# bus routes are needed to make people leave their cars at home? How much would that reduce the gas
# emissions (make your own reasonable assumptions)?

# %% [markdown]
# ### Calculating commuting distance
#
# Assumptions:
#
# 1. All people work in downtown Kingston, for simplicity the downtown transfer station is taken as the destination coordinates for every person's commute.
#
# 2. Each driveway has two cars; driveway coordinates are taken from the "driveways" dataset from the City of Kingston.
#
# 3. New bus routes will be added from the centroid of each neighborhood to the downtown transfer point.
#
# 4. A conversion factor of 1.3 is used to compensate for the use of Euclidean distances.
#
# 5. The capacity of a transit bus is 76 (https://www.dimensions.com/element/city-transit-buses)
#
# 6. The average fuel efficiency of the commuting vehicles is 8.9L/100km (11.286 km/l) (https://www.cer-rec.gc.ca/en/data-analysis/energy-markets/market-snapshots/2019/market-snapshot-how-does-canada-rank-in-terms-vehicle-fuel-economy.html#:~:text=In%202017%2C%20Canada%27s%20average,kilometres%20(L%2F100km).&text=In%20comparison%2C%20fuel%20consumption%20averaged,4.9%20L%2F100km%20in%20Portugal.)
#
# 7. Fuel efficiency of a transit bus is 3.26 mpg (1.4878 km/l) (https://www.bts.gov/content/bus-fuel-consumption-and-travel-metric)
#
# 8. All cars use gasoline as fuel, producing 2.29 kg of CO2 per liter of consumption. (https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/files/oee/pdf/transportation/fuel-efficient-technologies/autosmart_factsheet_6_e.pdf)
#
# 9. All transit busses use diesel as fuel, producing 2.66 kg CO2 per liter of consumption. (https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/files/oee/pdf/transportation/fuel-efficient-technologies/autosmart_factsheet_6_e.pdf)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from turfpy.measurement import boolean_point_in_polygon, centroid, distance
from geojson import Point, Polygon, Feature, load, LineString 
from geojson.utils import coords
plt.style.use('fivethirtyeight')
# %matplotlib inline
# Change to the Datasets folder of this directory
# %cd "C:\Users\mcunningham\Documents\PythonProjects\CISC451\Datasets"
# Out:
# C:\Users\mcunningham\Documents\PythonProjects\CISC451\Datasets

# %%
BUS_TOTAL_CAP = 76
CARTESIAN_CONVERSION_FACTOR = 1.3
CAR_EFFICIENCY = 11.286
BUS_EFFICIENCY = 1.4878
CAR_EMISSIONS = 2.29
BUS_EMISSIONS = 2.66
TRIPS_PER_DAY = 2
CARS_PER_DRIVEWAY = 2

# %%
# load points of interest dataset
df = pd.read_csv("point-of-interest.csv", ';')
# Get the downtown transfer point's coordinates
downtown_point = df.loc[df['NAME'] == 'DOWNTOWN TRANSFER POINT', 'geo_point_2d'].values[0]
# convert to a tuple of floats
downtown_lon = float(downtown_point.split(',')[0])
downtown_lat = float(downtown_point.split(',')[1])
downtown_coords = (downtown_lat, downtown_lon)
# Create geojson feature for the downtown transit point
dt = Feature(geometry=Point(downtown_coords))
print(dt)
# Out:
# {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.484538, 44.231033], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}

# %% [markdown]
# #### Cleaning the driveway dataset

# %%
df = pd.read_csv("driveways.csv", ';')
df.isna().sum()
# Out:
# ﻿&quot;STATUS&quot;       2
# MATERIAL        1
# GeoJSON         3
# geo_point_2d    3
# dtype: int64

# %% [markdown]
# We only want active driveways so we filter for those, and then check for any missing values.

# %%
df.drop(df[df[df.keys()[0]] != 'ACTIVE'].index, inplace=True)
df.isna().sum()
# Out:
# ﻿&quot;STATUS&quot;       0
# MATERIAL        0
# GeoJSON         3
# geo_point_2d    3
# dtype: int64

# %% [markdown]
# Since there are only three missing values, we decided to drop the rows

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# ﻿&quot;STATUS&quot;       0
# MATERIAL        0
# GeoJSON         0
# geo_point_2d    0
# dtype: int64

# %% [markdown]
# Now we convert the "geo_point_2d" column into a list of tuples containing latitude and longitude coordinates of type float.

# %%
driveway_coords = df['geo_point_2d'].str.split(',', expand=True).astype(float).rename(columns={0:'Latitude', 1:'Longitude'})
print(len(driveway_coords))
# Out:
# 45296

# %% [markdown]
# Load neighbourhood geojson and calculate the centroid as well as the distance between the centroid and the downtown transfer point.

# %%
with open("A1_geo\\neighbourhoods.geojson") as n:
    neighbourhoods = load(n)
for neighbourhood in neighbourhoods['features']:
    prop = neighbourhood['properties']
    # Create keys in neighbourhoods dict for key metrics
    prop['driveway_count'] = 0
    prop['commuter_distance'] = 0
    # Calculate centroid of each neighbourhood
    prop['centroid'] = centroid(neighbourhood)
    # Calculate the distance between the neighbourhood centroid and the downtown transfer point
    prop['distance_to_downtown'] = distance(prop['centroid'], dt) * CARTESIAN_CONVERSION_FACTOR
    # output
    print(f"{prop['name']}\nCentroid: {prop['centroid']}\nDistance: {prop['distance_to_downtown']}")
# Out:
# Marker&#39;s Acres
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.464708, 44.273464], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 6.46808412100974
# Polson Park
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.532533, 44.234207], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.992192402
# Reddendale
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.564105, 44.21394], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 8.604916790633462
# Rideau Heights
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.462188, 44.265945], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 5.551987837658764
# Williamsville
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.499471, 44.238587], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 1.8932544633882837
# Alwington
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.505435, 44.221421], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 2.5721992980973587
# Fairway Hills
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.535905, 44.223256], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 5.4382768558444745
# Westwoods
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.599266, 44.256251], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 12.427356959245714
# Ravensview
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.396776, 44.252695], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 9.612791832494684
# Ravensview
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.39764, 44.244933], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 9.221181367911596
# Mile Square
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.620417, 44.237288], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 14.102261986583159
# Joyceville / Brewer&#39;s Mills
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.267841, 44.38406], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 31.49260216166724
# Grenville Park
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.535784, 44.246934], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 5.783580634491016
# Waterloo Village
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.55109, 44.254352], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 7.672100845513102
# St. Lawrence North
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.378485, 44.261819], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 11.849257775366285
# Auden Park
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.58522, 44.23401], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 10.436992237203457
# Queen&#39;s
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.495791, 44.226017], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 1.3727273269033176
# Bayridge East
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.580854, 44.243481], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 10.13610379031057
# Greenwood Park / St. Lawrence South
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.41724, 44.267487], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 8.736517209427598
# Cataraqui Westbrook
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.646113, 44.27776], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 18.041041007169643
# Lemoine Point
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.608011, 44.229121], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 12.792206582338
# Glenburnie
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.443172, 44.319651], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 13.506569215441164
# Portsmouth
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.520134, 44.219314], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.057827114680688
# CFB Kingston
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.443252, 44.240525], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.490705178420199
# CFB Kingston
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.452827, 44.226653], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 3.3451307926688467
# Cataraqui River East
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.455971, 44.251764], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.2109899295571
# Elginburg / Silvers Corners / Shannon&#39;s Corners
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.48691, 44.302856], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 10.385176513469098
# Gardiners / Meadowbrook
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.564696, 44.247223], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 8.62499944655232
# Hillendale
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.526723, 44.245237], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.827313439780343
# Inner Harbour
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.474693, 44.24142], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 1.8149605089179657
# Calvin Park
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.520897, 44.235341], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 3.8169754635293094
# Henderson
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.578724, 44.222391], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 9.83591117656968
# Bayridge West
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.60184, 44.244318], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 12.299313918731693
# Sydenham
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.484204, 44.226059], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 0.7198414756589885
# Sunnyside
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.508407, 44.231661], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 2.473942184168065
# Sutton Mills
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.576129, 44.253189], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 10.01110266367909
# Strathcona Park
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.52626, 44.251909], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 5.270188173311731
# Kingston Mills
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.41099, 44.312583], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 14.032720138050797
# Sharpton / Glenvale
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.611502, 44.324126], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 18.80833724167747
# Cataraqui North
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.554528, 44.269559], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 9.139677688111655
# St. Lawrence North
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.332242, 44.291726], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 18.0429527175234
# Woodbine
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.623167, 44.256137], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 14.807322853087411
# Kingston Penitentiary
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.514256, 44.219488], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 3.50168146309145
# Collins Bay Penitentiary
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.554523, 44.228683], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 7.256964868161361
# Kingscourt / Novelis (Alcan)
# Centroid: {&quot;geometry&quot;: {&quot;coordinates&quot;: [-76.50989, 44.256267], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}
# Distance: 4.494199611833415

# %% [markdown]
# Now we calculate which neighbourhood each driveway is located within.
#
# Assumptions:
#
# 1. There are 2 cars for every driveway in Kingston
#
# 2. A conversion factor of 1.3 is used to compensate for the use of euclidean distances

# %%
for driveway in zip(driveway_coords['Longitude'], driveway_coords['Latitude']):
    # convert tuple to a geojson feature
    driveway = Feature(geometry=Point(driveway))
    # Check if driveway is located within each neighbourhood
    for neighbourhood in neighbourhoods['features']:
        if boolean_point_in_polygon(driveway, neighbourhood):
            # Increment driveway count for the neighbourhood
            neighbourhood['properties']['driveway_count'] += 1
            # Add up all the car milage for each driveway in the neighbourhood
            # (2 cars per driveway) 
            neighbourhood['properties']['commuter_distance'] += CARS_PER_DRIVEWAY * distance(driveway, dt) * CARTESIAN_CONVERSION_FACTOR
            break

# %% [markdown]
# Bus capacity taken from https://www.dimensions.com/element/city-transit-buses

# %%
from math import ceil
# initiate lists for creating a dataframe
names = []
driveway_count = []
busses_required = []
commuting_distance = []
tansit_distance = []
bus_routes = []
# loop through neighbourhoods and calculate metrics
for neighbourhood in neighbourhoods['features']:
    prop = neighbourhood['properties']
    # Calculate how many busses are required to handle all commuters (2 people per driveway)
    prop['busses_required'] = ceil(prop['driveway_count'] * CARS_PER_DRIVEWAY / BUS_TOTAL_CAP)
    # Create bus route and append to list
    centroid_coords = list(coords(prop['centroid']))[0]
    bus_routes.append((LineString([centroid_coords, downtown_coords]), prop['busses_required']))
    # Calculate how many km will be traveled by these busses
    prop['transit_stand_distance'] = prop['busses_required'] * prop['distance_to_downtown']
    # Output metrics
    print(
        f"{prop['name']}\n"
        f"Driveways:\t\t\t\t{prop['driveway_count']}\n"
        f"Busses Required:\t\t\t{prop['busses_required']}\n"
        f"Commute Distance (km):\t\t\t{prop['commuter_distance']}\n"
        f"Transit Distance Standing room (km):\t{prop['transit_stand_distance']}\n"
    )
    # Append values to lists to be used in DataFrame
    names.append(prop['name'])
    busses_required.append(prop['busses_required'])
    driveway_count.append(prop['driveway_count'])
    commuting_distance.append(prop['commuter_distance'])
    tansit_distance.append(prop['transit_stand_distance'])
# Out:
# Marker&#39;s Acres
# Driveways:				1080
# Busses Required:			29
# Commute Distance (km):			12046.197025131267
# Transit Distance Standing room (km):	187.57443950928246
#
# Polson Park
# Driveways:				398
# Busses Required:			11
# Commute Distance (km):			3759.1643697537993
# Transit Distance Standing room (km):	54.914116422
#
# Reddendale
# Driveways:				592
# Busses Required:			16
# Commute Distance (km):			10846.383245070781
# Transit Distance Standing room (km):	137.6786686501354
#
# Rideau Heights
# Driveways:				1363
# Busses Required:			36
# Commute Distance (km):			11326.788345649604
# Transit Distance Standing room (km):	199.8715621557155
#
# Williamsville
# Driveways:				453
# Busses Required:			12
# Commute Distance (km):			1675.6173581923968
# Transit Distance Standing room (km):	22.719053560659404
#
# Alwington
# Driveways:				425
# Busses Required:			12
# Commute Distance (km):			2161.1377652922015
# Transit Distance Standing room (km):	30.866391577168304
#
# Fairway Hills
# Driveways:				489
# Busses Required:			13
# Commute Distance (km):			4969.576245235167
# Transit Distance Standing room (km):	70.69759912597817
#
# Westwoods
# Driveways:				2220
# Busses Required:			59
# Commute Distance (km):			54819.90102764282
# Transit Distance Standing room (km):	733.2140605954971
#
# Ravensview
# Driveways:				371
# Busses Required:			10
# Commute Distance (km):			6867.9071143095425
# Transit Distance Standing room (km):	96.12791832494685
#
# Ravensview
# Driveways:				0
# Busses Required:			0
# Commute Distance (km):			0
# Transit Distance Standing room (km):	0.0
#
# Mile Square
# Driveways:				967
# Busses Required:			26
# Commute Distance (km):			26911.576121502207
# Transit Distance Standing room (km):	366.6588116511621
#
# Joyceville / Brewer&#39;s Mills
# Driveways:				880
# Busses Required:			24
# Commute Distance (km):			51653.38480190139
# Transit Distance Standing room (km):	755.8224518800138
#
# Grenville Park
# Driveways:				310
# Busses Required:			9
# Commute Distance (km):			3266.201617929379
# Transit Distance Standing room (km):	52.052225710419144
#
# Waterloo Village
# Driveways:				734
# Busses Required:			20
# Commute Distance (km):			11205.04468024115
# Transit Distance Standing room (km):	153.44201691026203
#
# St. Lawrence North
# Driveways:				0
# Busses Required:			0
# Commute Distance (km):			0
# Transit Distance Standing room (km):	0.0
#
# Auden Park
# Driveways:				2054
# Busses Required:			55
# Commute Distance (km):			42871.24235080034
# Transit Distance Standing room (km):	574.0345730461901
#
# Queen&#39;s
# Driveways:				397
# Busses Required:			11
# Commute Distance (km):			1024.5828539791894
# Transit Distance Standing room (km):	15.100000595936493
#
# Bayridge East
# Driveways:				1451
# Busses Required:			39
# Commute Distance (km):			30715.051481086328
# Transit Distance Standing room (km):	395.3080478221122
#
# Greenwood Park / St. Lawrence South
# Driveways:				2962
# Busses Required:			78
# Commute Distance (km):			40311.60649259212
# Transit Distance Standing room (km):	681.4483423353527
#
# Cataraqui Westbrook
# Driveways:				4130
# Busses Required:			109
# Commute Distance (km):			101766.37073075795
# Transit Distance Standing room (km):	1966.473469781491
#
# Lemoine Point
# Driveways:				611
# Busses Required:			17
# Commute Distance (km):			13815.012218690446
# Transit Distance Standing room (km):	217.467511899746
#
# Glenburnie
# Driveways:				335
# Busses Required:			9
# Commute Distance (km):			7965.455933343419
# Transit Distance Standing room (km):	121.55912293897048
#
# Portsmouth
# Driveways:				907
# Busses Required:			24
# Commute Distance (km):			7152.511963328888
# Transit Distance Standing room (km):	97.3878507523365
#
# CFB Kingston
# Driveways:				615
# Busses Required:			17
# Commute Distance (km):			5149.68396581946
# Transit Distance Standing room (km):	76.34198803314338
#
# CFB Kingston
# Driveways:				0
# Busses Required:			0
# Commute Distance (km):			0
# Transit Distance Standing room (km):	0.0
#
# Cataraqui River East
# Driveways:				1077
# Busses Required:			29
# Commute Distance (km):			9499.116361791992
# Transit Distance Standing room (km):	122.1187079571559
#
# Elginburg / Silvers Corners / Shannon&#39;s Corners
# Driveways:				1049
# Busses Required:			28
# Commute Distance (km):			24634.69738320673
# Transit Distance Standing room (km):	290.7849423771347
#
# Gardiners / Meadowbrook
# Driveways:				2038
# Busses Required:			54
# Commute Distance (km):			31543.769879409945
# Transit Distance Standing room (km):	465.74997011382527
#
# Hillendale
# Driveways:				406
# Busses Required:			11
# Commute Distance (km):			4003.7871045569304
# Transit Distance Standing room (km):	53.10044783758377
#
# Inner Harbour
# Driveways:				1187
# Busses Required:			32
# Commute Distance (km):			2959.0848313568263
# Transit Distance Standing room (km):	58.0787362853749
#
# Calvin Park
# Driveways:				952
# Busses Required:			26
# Commute Distance (km):			7506.660383278917
# Transit Distance Standing room (km):	99.24136205176204
#
# Henderson
# Driveways:				1545
# Busses Required:			41
# Commute Distance (km):			30062.020146469345
# Transit Distance Standing room (km):	403.27235823935683
#
# Bayridge West
# Driveways:				1335
# Busses Required:			36
# Commute Distance (km):			32234.239611083605
# Transit Distance Standing room (km):	442.775301074341
#
# Sydenham
# Driveways:				259
# Busses Required:			7
# Commute Distance (km):			290.8985503512375
# Transit Distance Standing room (km):	5.0388903296129195
#
# Sunnyside
# Driveways:				1685
# Busses Required:			45
# Commute Distance (km):			8145.355727398696
# Transit Distance Standing room (km):	111.32739828756291
#
# Sutton Mills
# Driveways:				1492
# Busses Required:			40
# Commute Distance (km):			31040.61471395239
# Transit Distance Standing room (km):	400.4441065471636
#
# Strathcona Park
# Driveways:				1282
# Busses Required:			34
# Commute Distance (km):			13266.512646616437
# Transit Distance Standing room (km):	179.18639789259888
#
# Kingston Mills
# Driveways:				504
# Busses Required:			14
# Commute Distance (km):			14000.398835910319
# Transit Distance Standing room (km):	196.45808193271117
#
# Sharpton / Glenvale
# Driveways:				1019
# Busses Required:			27
# Commute Distance (km):			36008.10023552814
# Transit Distance Standing room (km):	507.8251055252917
#
# Cataraqui North
# Driveways:				2231
# Busses Required:			59
# Commute Distance (km):			38157.18472780959
# Transit Distance Standing room (km):	539.2409835985877
#
# St. Lawrence North
# Driveways:				955
# Busses Required:			26
# Commute Distance (km):			33846.42719952308
# Transit Distance Standing room (km):	469.1167706556084
#
# Woodbine
# Driveways:				318
# Busses Required:			9
# Commute Distance (km):			9139.912230893087
# Transit Distance Standing room (km):	133.2659056777867
#
# Kingston Penitentiary
# Driveways:				7
# Busses Required:			1
# Commute Distance (km):			48.30995684420853
# Transit Distance Standing room (km):	3.50168146309145
#
# Collins Bay Penitentiary
# Driveways:				25
# Busses Required:			1
# Commute Distance (km):			370.5482491279857
# Transit Distance Standing room (km):	7.256964868161361
#
# Kingscourt / Novelis (Alcan)
# Driveways:				1909
# Busses Required:			51
# Commute Distance (km):			12025.309637023089
# Transit Distance Standing room (km):	229.20418020350417

# %%
import plotly.graph_objects as go
import json
# Load geojson files for the background layers
with open("A1_geo\\neighbourhoods.geojson", "r") as geo:
    neighbourhood_geojson = json.load(geo)

# %%
colors = [
    "blue",
    "darkred",
    "darkblue",
    "darkviolet",
    "darkmagenta",
    "royalblue",
    "firebrick",
    "forestgreen",
    "darkturquoise",
    "darkorange",
    "darkslateblue",
    "darkgreen",
    "fuchsia",
    "green",
    "greenyellow",
    "indianred",
    "lavenderblush",
    "lawngreen",
    "lightgreen",
    "lightseagreen",
    "lime",
    "limegreen",
    "magenta",
    "maroon",
    "mediumaquamarine",
    "mediumblue",
    "mediumpurple",
    "mediumseagreen",
    "mediumslateblue",
    "mediumspringgreen",
    "mediumturquoise",
    "mediumvioletred",
    "midnightblue",
    "navy",
    "orange",
    "orangered",
    "darkmagenta",
    "darkslategrey",
    "purple",
    "red",
    "seagreen",
    "darkseagreen",
    "teal",
    "tomato",
    "steelblue",
    "black"
]
layers = []
for n, neighbourhood in enumerate(neighbourhood_geojson['features']):
    layers.append(
        {
            'visible': True,
            'source': neighbourhood,
            'type': "fill",
            'below': "traces",
            'color': colors[n],
            'opacity': 0.2
        }
    )
# Create a list of features for each proposed bus route (to color each individually)
for n, route in enumerate(bus_routes):
    layers.append(
        {
            'visible': True,
            'source': route[0],
            'type': "line",
            'below': "traces",
            'color': colors[n],
            'opacity': 0.7,
            'line': {'width': route[1]/10}
        }
    )

# %%
# Create a plotly Scattermapbox plot for displaying the proposed routes
fig = go.Figure(go.Scattermapbox(lon = [0], lat = [0]))
# Specify stylistic preferences and add in background layers (routes)
fig.update_layout(
    height=700,
    mapbox = {
        'style': "carto-positron",
        'center': {"lat": 44.227860, "lon": -76.496938},
        'zoom': 11,
        'layers': layers
        },
    margin = {'l':0, 'r':0, 'b':0, 't':0})
# Use more efficient rendering widget
f = go.FigureWidget(fig)
f
# Out:
# FigureWidget({
#     &#39;data&#39;: [{&#39;lat&#39;: [0], &#39;lon&#39;: [0], &#39;type&#39;: &#39;scattermapbox&#39;, &#39;uid&#39;: &#39;1f20d49f-8b6a-4f48-b83a-…

# %% [markdown]
# Create Datafrsme and plot results.
#
# **Assumptions:**
#
# 1. Fuel ifficiency of the average car is 8.9L/100km (11.286 km/l) ()
#
# 2. Fuel efficiency of a city bus is 3.26 mpg (1.4878 km/l) (https://www.bts.gov/content/bus-fuel-consumption-and-travel-metric)
#
# 3. All cars use gasoline as fuel, producing 2.29 kg of CO2 per liter of consumption. (https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/files/oee/pdf/transportation/fuel-efficient-technologies/autosmart_factsheet_6_e.pdf)
#
# 4. All transit busses use diesel as fuel, producing 2.66 kg CO2 per liter of consumption. (https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/files/oee/pdf/transportation/fuel-efficient-technologies/autosmart_factsheet_6_e.pdf)

# %%
# Create DataFrame
commute_df = pd.DataFrame({'Neighbourhood': names, 'Number of Driveways': driveway_count, 'Busses Required': busses_required, 'Commuting Distance': commuting_distance, 'Transit Distance': tansit_distance})
# Calculate commute/transit fuel consumption for each neighbourhood
commute_df['Commute Consumption'] = TRIPS_PER_DAY * commute_df['Commuting Distance'] / CAR_EFFICIENCY
commute_df['Transit Consumption'] = TRIPS_PER_DAY * commute_df['Transit Distance'] / BUS_EFFICIENCY
# And CO2 emissions
commute_df['Commute Emissions'] = commute_df['Commute Consumption'] * CAR_EMISSIONS
commute_df['Transit Emissions'] = commute_df['Transit Consumption'] * BUS_EMISSIONS
commute_df.head()
# Out:
#     Neighbourhood  Number of Driveways  Busses Required  Commuting Distance  \
# 0  Marker&#39;s Acres                 1080               29        12046.197025
# 1     Polson Park                  398               11         3759.164370
# 2      Reddendale                  592               16        10846.383245
# 3  Rideau Heights                 1363               36        11326.788346
# 4   Williamsville                  453               12         1675.617358
#
#    Transit Distance  Commute Consumption  Transit Consumption  \
# 0        187.574440          2134.715050           252.150073
# 1         54.914116           666.164163            73.819218
# 2        137.678669          1922.095206           185.076850
# 3        199.871562          2007.228131           268.680686
# 4         22.719054           296.937331            30.540467
#
#    Commute Emissions  Transit Emissions
# 0        4888.497464         670.719195
# 1        1525.515932         196.359120
# 2        4401.598021         492.304421
# 3        4596.552421         714.690624
# 4         679.986488          81.237643

# %%
commute_df[['Neighbourhood', 'Busses Required']].plot(kind='barh', x='Neighbourhood', figsize=(10, 8))
# Out:
# &lt;AxesSubplot:ylabel=&#39;Neighbourhood&#39;&gt;
# &lt;Figure size 720x576 with 1 Axes&gt;

# %%
commute_df[['Neighbourhood', 'Commute Consumption', 'Transit Consumption']].plot(kind='barh', x='Neighbourhood', figsize=(10, 8.2))
# Out:
# &lt;AxesSubplot:ylabel=&#39;Neighbourhood&#39;&gt;
# &lt;Figure size 720x590.4 with 1 Axes&gt;

# %%
commute_df[['Commute Emissions', 'Transit Emissions']].sum().plot.pie()
# Out:
# &lt;AxesSubplot:ylabel=&#39;None&#39;&gt;
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection


def nested_circles(data, labels=None, c=None, ax=None, 
                   cmap=None, norm=None, textkw={}):
    """ Create a nested circles plot for for the given data
    """
    ax = ax or plt.gca()
    data = np.array(data)
    R = np.sqrt(data/data.max())
    p = [plt.Circle((0,r), radius=r) for r in R[::-1]]
    arr = data[::-1] if c is None else np.array(c[::-1])
    col = PatchCollection(p, cmap=cmap, norm=norm, array=arr)

    ax.add_collection(col)
    ax.axis("off")
    ax.set_aspect("equal")
    ax.autoscale()

    if labels is not None:
        kw = dict(color="white", va="center", ha="center")
        kw.update(textkw)
        ax.text(0, R[0], labels[0], **kw)
        for i in range(1, len(R)):
            ax.text(0, R[i]+R[i-1], labels[i], **kw)
    return col
bus_emissions = commute_df['Transit Emissions'].sum()
car_emissions = commute_df['Commute Emissions'].sum()
data = [bus_emissions, car_emissions]
labels = [
    f'Transit Emissions\n{round(bus_emissions)} kg CO2',
    f'Commute Emissions\n{round(car_emissions)} kg CO2'
    ]
nested_circles(data, labels=labels, cmap="seismic_r", textkw=dict(fontsize=12))
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;
